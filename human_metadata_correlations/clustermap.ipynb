# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re


plt.rcParams['svg.fonttype'] = 'none'

# %%
data = pd.read_csv("data/corr_clustermap.tsv",sep='\t',index_col=0)

# %%
sns.clustermap(data.corr(),annot=True,figsize=(12,12),dendrogram_ratio=0.1,cmap="vlag")
